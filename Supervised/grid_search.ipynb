# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

from joblib import dump, load

# %%
df = pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/house_pricing.csv")
df.info()
df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 814 entries, 0 to 813
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        814 non-null    object
#  1   Type        814 non-null    object
#  2   Beds        814 non-null    int64
#  3   Baths       814 non-null    int64
#  4   SquareFeet  814 non-null    int64
#  5   Price       814 non-null    float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 38.3+ KB
#          City         Type  Beds  Baths  SquareFeet      Price
# 0  SACRAMENTO  Residential     2      1         836  138159.85
# 1  SACRAMENTO  Residential     3      1        1167  167541.46

# %%
# Feature selection (X, y) & Split into xtrain,xtest,ytrain,ytest
X = df[['Beds','Baths','SquareFeet']]
y = df['Price']
xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=.2, random_state=1)

# %%
print('Random Forest')
model2 = RandomForestRegressor()
model2.fit(xtrain,ytrain)
print('score:', model2.score(xtest, ytest) * 100)
pred = model2.predict(X)
print('mse:', mean_squared_error(y,pred))
print('mae:', mean_absolute_error(y,pred))
# Out:
# Random Forest
# score: 72.48084505601993
# mse: 824386758.4534308
# mae: 15244.083094266876

# %% [markdown]
# ### Grid Search

# %%
# We are going to create a dictionary with all the parameteer and their value options

# %%
params = {
    'n_estimators' : list(range(100,501,100)),
    'criterion': ['squared_error','absolute_error','poisson'],
    'max_depth': list(range(5,51,15))
}
params
# Out:
# {'n_estimators': [100, 200, 300, 400, 500],
#  'criterion': ['squared_error', 'absolute_error', 'poisson'],
#  'max_depth': [5, 20, 35, 50]}

# %%
grid = GridSearchCV(estimator=RandomForestRegressor(),param_grid=params,cv=3,n_jobs=-1,verbose=2)

# %%
grid.fit(X,y)
# Out:
# Fitting 3 folds for each of 60 candidates, totalling 180 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': [5, 20, 35, 50],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              verbose=2)

# %%
grid.cv_results_
# Out:
# {'mean_fit_time': array([0.52445904, 1.00696127, 1.41687298, 1.96230141, 1.78897587,
#         0.56748923, 0.53239473, 0.80258449, 1.05935677, 1.43348606,
#         0.26072049, 0.84992496, 1.62994138, 2.36841639, 2.93191727,
#         0.60978715, 1.14047615, 1.12909166, 1.14878058, 1.42105548,
#         0.55540331, 1.72494626, 3.26951559, 4.47354349, 4.29348548,
#         1.14009476, 2.19166787, 4.40182527, 6.0207332 , 7.0047524 ,
#         1.09280133, 3.10807657, 3.28276443, 4.77830831, 6.18655252,
#         1.64709504, 2.33022388, 3.31132746, 5.7435232 , 7.30924869,
#         0.45871822, 0.90047375, 1.03435334, 0.85362299, 1.99458758,
#         0.74754175, 1.42842897, 2.17721891, 2.2173152 , 2.16671316,
#         0.44722374, 0.82403652, 1.46665589, 2.96475736, 3.99485175,
#         1.01239014, 2.02703325, 2.4909145 , 2.23380423, 2.20556474]),
#  'std_fit_time': array([0.02332155, 0.02694099, 0.02067539, 0.15146491, 0.11860954,
#         0.0530902 , 0.00673103, 0.00872643, 0.01839393, 0.1657482 ,
#         0.00318437, 0.07702411, 0.16046468, 0.04743547, 0.14965469,
#         0.03316355, 0.01703181, 0.22266834, 0.05046803, 0.05062576,
#         0.00806295, 0.11563006, 0.1067206 , 0.29747031, 0.37781678,
#         0.22969228, 0.24731418, 0.08685018, 0.03448476, 0.49748877,
#         0.24616077, 0.1558834 , 0.31885939, 0.23428941, 0.10456297,
#         0.18189059, 0.14116201, 0.45132892, 0.13898482, 0.2248154 ,
#         0.01211984, 0.04958928, 0.19388499, 0.02260845, 0.31555293,
#         0.00221249, 0.05498623, 0.08757562, 0.09572332, 0.2813748 ,
#         0.0469245 , 0.01573748, 0.24967162, 0.19252352, 0.3021101 ,
#         0.03370618, 0.12083436, 0.19135914, 0.17330865, 0.08015775]),
#  'mean_score_time': array([0.03805677, 0.08014282, 0.10906458, 0.06352989, 0.06977717,
#         0.02678919, 0.03288722, 0.0501016 , 0.06885417, 0.19197249,
#         0.02431043, 0.07625516, 0.11494501, 0.16926249, 0.13253029,
#         0.05093582, 0.03878363, 0.05739872, 0.076358  , 0.11206659,
#         0.01679174, 0.0732549 , 0.11446428, 0.0600512 , 0.13463378,
#         0.01757598, 0.07227015, 0.09134618, 0.15283354, 0.11275721,
#         0.03502886, 0.04949832, 0.07503287, 0.149067  , 0.08138355,
#         0.04038254, 0.03709737, 0.11060516, 0.12429531, 0.19977323,
#         0.03370269, 0.06059488, 0.0372359 , 0.07437968, 0.15679487,
#         0.04359643, 0.06816665, 0.09136899, 0.0567352 , 0.08253439,
#         0.0247697 , 0.03466916, 0.09845336, 0.15283879, 0.18906808,
#         0.04531582, 0.09563128, 0.05751729, 0.06750385, 0.08455483]),
#  'std_score_time': array([0.0042969 , 0.008634  , 0.0049403 , 0.00387542, 0.00377152,
#         0.01450052, 0.0006278 , 0.00058561, 0.00447071, 0.0063532 ,
#         0.00042671, 0.00552592, 0.00314154, 0.00561348, 0.03504526,
#         0.01201958, 0.00404333, 0.00655348, 0.00010443, 0.04749065,
#         0.00070186, 0.00951424, 0.02617676, 0.00366422, 0.04302685,
#         0.00112586, 0.00449453, 0.02970458, 0.00489395, 0.05228116,
#         0.01311012, 0.02304346, 0.02691621, 0.00234619, 0.00125692,
#         0.00053065, 0.00275744, 0.00673676, 0.03631848, 0.01084162,
#         0.00553352, 0.00529756, 0.00369974, 0.0259928 , 0.00910394,
#         0.00326011, 0.00376913, 0.03296368, 0.00052105, 0.00280196,
#         0.00104858, 0.00376978, 0.03540573, 0.00915986, 0.0182018 ,
#         0.00387349, 0.01032592, 0.00479468, 0.0039973 , 0.02956087]),
#  'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'squared_error',
#                     'squared_error', 'squared_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'absolute_error', 'absolute_error',
#                     'absolute_error', 'poisson', 'poisson', 'poisson',
#                     'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                     'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                     'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                     'poisson', 'poisson'],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_max_depth': masked_array(data=[5, 5, 5, 5, 5, 20, 20, 20, 20, 20, 35, 35, 35, 35, 35,
#                     50, 50, 50, 50, 50, 5, 5, 5, 5, 5, 20, 20, 20, 20, 20,
#                     35, 35, 35, 35, 35, 50, 50, 50, 50, 50, 5, 5, 5, 5, 5,
#                     20, 20, 20, 20, 20, 35, 35, 35, 35, 35, 50, 50, 50, 50,
#                     50],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[100, 200, 300, 400, 500, 100, 200, 300, 400, 500, 100,
#                     200, 300, 400, 500, 100, 200, 300, 400, 500, 100, 200,
#                     300, 400, 500, 100, 200, 300, 400, 500, 100, 200, 300,
#                     400, 500, 100, 200, 300, 400, 500, 100, 200, 300, 400,
#                     500, 100, 200, 300, 400, 500, 100, 200, 300, 400, 500,
#                     100, 200, 300, 400, 500],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False, False, False, False, False,
#                     False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'criterion': 'squared_error',
#    'max_depth': 5,
#    'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_depth': 5, 'n_estimators': 200},
#   {'criterion': 'squared_error', 'max_depth': 5, 'n_estimators': 300},
#   {'criterion': 'squared_error', 'max_depth': 5, 'n_estimators': 400},
#   {'criterion': 'squared_error', 'max_depth': 5, 'n_estimators': 500},
#   {'criterion': 'squared_error', 'max_depth': 20, 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_depth': 20, 'n_estimators': 200},
#   {'criterion': 'squared_error', 'max_depth': 20, 'n_estimators': 300},
#   {'criterion': 'squared_error', 'max_depth': 20, 'n_estimators': 400},
#   {'criterion': 'squared_error', 'max_depth': 20, 'n_estimators': 500},
#   {'criterion': 'squared_error', 'max_depth': 35, 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_depth': 35, 'n_estimators': 200},
#   {'criterion': 'squared_error', 'max_depth': 35, 'n_estimators': 300},
#   {'criterion': 'squared_error', 'max_depth': 35, 'n_estimators': 400},
#   {'criterion': 'squared_error', 'max_depth': 35, 'n_estimators': 500},
#   {'criterion': 'squared_error', 'max_depth': 50, 'n_estimators': 100},
#   {'criterion': 'squared_error', 'max_depth': 50, 'n_estimators': 200},
#   {'criterion': 'squared_error', 'max_depth': 50, 'n_estimators': 300},
#   {'criterion': 'squared_error', 'max_depth': 50, 'n_estimators': 400},
#   {'criterion': 'squared_error', 'max_depth': 50, 'n_estimators': 500},
#   {'criterion': 'absolute_error', 'max_depth': 5, 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_depth': 5, 'n_estimators': 200},
#   {'criterion': 'absolute_error', 'max_depth': 5, 'n_estimators': 300},
#   {'criterion': 'absolute_error', 'max_depth': 5, 'n_estimators': 400},
#   {'criterion': 'absolute_error', 'max_depth': 5, 'n_estimators': 500},
#   {'criterion': 'absolute_error', 'max_depth': 20, 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_depth': 20, 'n_estimators': 200},
#   {'criterion': 'absolute_error', 'max_depth': 20, 'n_estimators': 300},
#   {'criterion': 'absolute_error', 'max_depth': 20, 'n_estimators': 400},
#   {'criterion': 'absolute_error', 'max_depth': 20, 'n_estimators': 500},
#   {'criterion': 'absolute_error', 'max_depth': 35, 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_depth': 35, 'n_estimators': 200},
#   {'criterion': 'absolute_error', 'max_depth': 35, 'n_estimators': 300},
#   {'criterion': 'absolute_error', 'max_depth': 35, 'n_estimators': 400},
#   {'criterion': 'absolute_error', 'max_depth': 35, 'n_estimators': 500},
#   {'criterion': 'absolute_error', 'max_depth': 50, 'n_estimators': 100},
#   {'criterion': 'absolute_error', 'max_depth': 50, 'n_estimators': 200},
#   {'criterion': 'absolute_error', 'max_depth': 50, 'n_estimators': 300},
#   {'criterion': 'absolute_error', 'max_depth': 50, 'n_estimators': 400},
#   {'criterion': 'absolute_error', 'max_depth': 50, 'n_estimators': 500},
#   {'criterion': 'poisson', 'max_depth': 5, 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_depth': 5, 'n_estimators': 200},
#   {'criterion': 'poisson', 'max_depth': 5, 'n_estimators': 300},
#   {'criterion': 'poisson', 'max_depth': 5, 'n_estimators': 400},
#   {'criterion': 'poisson', 'max_depth': 5, 'n_estimators': 500},
#   {'criterion': 'poisson', 'max_depth': 20, 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_depth': 20, 'n_estimators': 200},
#   {'criterion': 'poisson', 'max_depth': 20, 'n_estimators': 300},
#   {'criterion': 'poisson', 'max_depth': 20, 'n_estimators': 400},
#   {'criterion': 'poisson', 'max_depth': 20, 'n_estimators': 500},
#   {'criterion': 'poisson', 'max_depth': 35, 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_depth': 35, 'n_estimators': 200},
#   {'criterion': 'poisson', 'max_depth': 35, 'n_estimators': 300},
#   {'criterion': 'poisson', 'max_depth': 35, 'n_estimators': 400},
#   {'criterion': 'poisson', 'max_depth': 35, 'n_estimators': 500},
#   {'criterion': 'poisson', 'max_depth': 50, 'n_estimators': 100},
#   {'criterion': 'poisson', 'max_depth': 50, 'n_estimators': 200},
#   {'criterion': 'poisson', 'max_depth': 50, 'n_estimators': 300},
#   {'criterion': 'poisson', 'max_depth': 50, 'n_estimators': 400},
#   {'criterion': 'poisson', 'max_depth': 50, 'n_estimators': 500}],
#  'split0_test_score': array([0.80909742, 0.80275799, 0.80082282, 0.8007883 , 0.80001861,
#         0.76412862, 0.75192494, 0.75525596, 0.74554056, 0.75555181,
#         0.74860972, 0.75768877, 0.76162984, 0.75771373, 0.74956502,
#         0.74339067, 0.76373307, 0.75384257, 0.75579886, 0.75487242,
#         0.82105554, 0.82166616, 0.82496516, 0.82599617, 0.82371856,
#         0.76905322, 0.75829652, 0.76399874, 0.76355903, 0.76077026,
#         0.78031856, 0.77378888, 0.76276749, 0.7627866 , 0.77052032,
#         0.76166035, 0.7640074 , 0.76688614, 0.76137869, 0.76237311,
#         0.34335822, 0.34747559, 0.33302101, 0.34195555, 0.34215239,
#         0.67632683, 0.67469206, 0.6743203 , 0.68082153, 0.67601966,
#         0.72300285, 0.74287982, 0.73835714, 0.74719597, 0.73335962,
#         0.73765016, 0.73282543, 0.73687369, 0.73473007, 0.73532433]),
#  'split1_test_score': array([0.76808306, 0.76532828, 0.76991611, 0.76701974, 0.76814491,
#         0.75419111, 0.75098741, 0.75280599, 0.75400193, 0.75409291,
#         0.75229655, 0.75411363, 0.7536649 , 0.75376457, 0.75348878,
#         0.75656739, 0.75537924, 0.75290266, 0.75613404, 0.75291731,
#         0.7645481 , 0.76871229, 0.76755234, 0.76770333, 0.76703186,
#         0.76003813, 0.75904078, 0.75814664, 0.76038221, 0.76020391,
#         0.75853063, 0.75770079, 0.75883886, 0.76049457, 0.75897486,
#         0.76071872, 0.75430318, 0.75944233, 0.75992891, 0.76070199,
#         0.50351406, 0.50001246, 0.49899524, 0.49936755, 0.50081144,
#         0.71926454, 0.71647128, 0.71658022, 0.71620139, 0.71705624,
#         0.7519894 , 0.74946446, 0.7548142 , 0.7538064 , 0.75189746,
#         0.75157675, 0.7561948 , 0.75645933, 0.75452067, 0.75382208]),
#  'split2_test_score': array([0.61833917, 0.61887842, 0.61810707, 0.61317649, 0.6149203 ,
#         0.58446021, 0.57558035, 0.58066726, 0.57964438, 0.5764532 ,
#         0.58360265, 0.57857089, 0.57502012, 0.58386395, 0.57569453,
#         0.57180274, 0.57860215, 0.57836828, 0.58036995, 0.58379006,
#         0.61339986, 0.61409672, 0.61326302, 0.61327859, 0.61440517,
#         0.57880666, 0.58221568, 0.57788666, 0.57283131, 0.57832664,
#         0.58284294, 0.57186009, 0.56871861, 0.58044524, 0.58004788,
#         0.57766783, 0.5691132 , 0.57582372, 0.57451491, 0.57470104,
#         0.16696482, 0.15855428, 0.16494316, 0.15339746, 0.16076271,
#         0.48416154, 0.49343434, 0.49366544, 0.48857494, 0.48978211,
#         0.57707625, 0.5776598 , 0.57397973, 0.5738355 , 0.57717274,
#         0.57595931, 0.57348435, 0.57199368, 0.57259776, 0.57434792]),
#  'mean_test_score': array([0.73183989, 0.72898823, 0.72961533, 0.72699484, 0.72769461,
#         0.70092665, 0.6928309 , 0.69624307, 0.69306229, 0.69536597,
#         0.69483631, 0.6967911 , 0.69677162, 0.69844741, 0.69291611,
#         0.69058693, 0.69923815, 0.69503784, 0.69743428, 0.69719326,
#         0.73300117, 0.73482505, 0.73526017, 0.73565937, 0.73505186,
#         0.70263267, 0.69985099, 0.70001068, 0.69892419, 0.69976693,
#         0.70723071, 0.70111658, 0.69677499, 0.70124214, 0.70318102,
#         0.70001564, 0.69580793, 0.7007174 , 0.6986075 , 0.69925871,
#         0.3379457 , 0.33534744, 0.3323198 , 0.33157352, 0.33457551,
#         0.6265843 , 0.62819922, 0.62818865, 0.62853262, 0.62761934,
#         0.68402283, 0.69000136, 0.68905036, 0.69161262, 0.68747661,
#         0.68839541, 0.68750153, 0.68844224, 0.68728283, 0.68783144]),
#  'std_test_score': array([0.08198518, 0.07934471, 0.07985143, 0.08165391, 0.08079817,
#         0.08245407, 0.08290954, 0.08173056, 0.08027294, 0.08408614,
#         0.07866847, 0.08360705, 0.0861527 , 0.08103878, 0.08290365,
#         0.08416519, 0.08537069, 0.08249873, 0.0827771 , 0.08019215,
#         0.08766081, 0.08806258, 0.08939253, 0.08974893, 0.0883933 ,
#         0.08763553, 0.08318129, 0.08638777, 0.08917056, 0.08587157,
#         0.08840406, 0.09163383, 0.09056373, 0.08542143, 0.08719577,
#         0.08651381, 0.08967425, 0.08836543, 0.08774871, 0.08807822,
#         0.13744895, 0.13966327, 0.13637709, 0.14143235, 0.13892766,
#         0.10222229, 0.09680756, 0.09667418, 0.10001349, 0.09889498,
#         0.07654295, 0.07948295, 0.08164413, 0.08332472, 0.07836292,
#         0.07970736, 0.08118485, 0.08272887, 0.08149608, 0.08059952]),
#  'rank_test_score': array([ 6,  8,  7, 10,  9, 16, 39, 32, 37, 34, 36, 29, 31, 26, 38, 41, 23,
#         35, 27, 28,  5,  4,  2,  1,  3, 13, 20, 19, 24, 21, 11, 15, 30, 14,
#         12, 18, 33, 17, 25, 22, 56, 57, 59, 60, 58, 55, 52, 53, 51, 54, 50,
#         42, 43, 40, 48, 45, 47, 44, 49, 46])}

# %%
gf = pd.DataFrame(grid.cv_results_)

# %%
gf.sort_values(by='rank_test_score', inplace=True)
gf
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 23       4.473543      0.297470         0.060051        0.003664
# 22       3.269516      0.106721         0.114464        0.026177
# 24       4.293485      0.377817         0.134634        0.043027
# 21       1.724946      0.115630         0.073255        0.009514
# 20       0.555403      0.008063         0.016792        0.000702
# 0        0.524459      0.023322         0.038057        0.004297
# 2        1.416873      0.020675         0.109065        0.004940
# 1        1.006961      0.026941         0.080143        0.008634
# 4        1.788976      0.118610         0.069777        0.003772
# 3        1.962301      0.151465         0.063530        0.003875
# 30       1.092801      0.246161         0.035029        0.013110
# 34       6.186553      0.104563         0.081384        0.001257
# 25       1.140095      0.229692         0.017576        0.001126
# 33       4.778308      0.234289         0.149067        0.002346
# 31       3.108077      0.155883         0.049498        0.023043
# 5        0.567489      0.053090         0.026789        0.014501
# 37       3.311327      0.451329         0.110605        0.006737
# 35       1.647095      0.181891         0.040383        0.000531
# 27       4.401825      0.086850         0.091346        0.029705
# 26       2.191668      0.247314         0.072270        0.004495
# 29       7.004752      0.497489         0.112757        0.052281
# 39       7.309249      0.224815         0.199773        0.010842
# 16       1.140476      0.017032         0.038784        0.004043
# 28       6.020733      0.034485         0.152834        0.004894
# 38       5.743523      0.138985         0.124295        0.036318
# 13       2.368416      0.047435         0.169262        0.005613
# 18       1.148781      0.050468         0.076358        0.000104
# 19       1.421055      0.050626         0.112067        0.047491
# 11       0.849925      0.077024         0.076255        0.005526
# 32       3.282764      0.318859         0.075033        0.026916
# 12       1.629941      0.160465         0.114945        0.003142
# 7        0.802584      0.008726         0.050102        0.000586
# 36       2.330224      0.141162         0.037097        0.002757
# 9        1.433486      0.165748         0.191972        0.006353
# 17       1.129092      0.222668         0.057399        0.006553
# 10       0.260720      0.003184         0.024310        0.000427
# 8        1.059357      0.018394         0.068854        0.004471
# 14       2.931917      0.149655         0.132530        0.035045
# 6        0.532395      0.006731         0.032887        0.000628
# 53       2.964757      0.192524         0.152839        0.009160
# 15       0.609787      0.033164         0.050936        0.012020
# 51       0.824037      0.015737         0.034669        0.003770
# 52       1.466656      0.249672         0.098453        0.035406
# 57       2.490915      0.191359         0.057517        0.004795
# 55       1.012390      0.033706         0.045316        0.003873
# 59       2.205565      0.080158         0.084555        0.029561
# 56       2.027033      0.120834         0.095631        0.010326
# 54       3.994852      0.302110         0.189068        0.018202
# 58       2.233804      0.173309         0.067504        0.003997
# 50       0.447224      0.046925         0.024770        0.001049
# 48       2.217315      0.095723         0.056735        0.000521
# 46       1.428429      0.054986         0.068167        0.003769
# 47       2.177219      0.087576         0.091369        0.032964
# 49       2.166713      0.281375         0.082534        0.002802
# 45       0.747542      0.002212         0.043596        0.003260
# 40       0.458718      0.012120         0.033703        0.005534
# 41       0.900474      0.049589         0.060595        0.005298
# 44       1.994588      0.315553         0.156795        0.009104
# 42       1.034353      0.193885         0.037236        0.003700
# 43       0.853623      0.022608         0.074380        0.025993
#
#    param_criterion param_max_depth param_n_estimators  \
# 23  absolute_error               5                400
# 22  absolute_error               5                300
# 24  absolute_error               5                500
# 21  absolute_error               5                200
# 20  absolute_error               5                100
# 0    squared_error               5                100
# 2    squared_error               5                300
# 1    squared_error               5                200
# 4    squared_error               5                500
# 3    squared_error               5                400
# 30  absolute_error              35                100
# 34  absolute_error              35                500
# 25  absolute_error              20                100
# 33  absolute_error              35                400
# 31  absolute_error              35                200
# 5    squared_error              20                100
# 37  absolute_error              50                300
# 35  absolute_error              50                100
# 27  absolute_error              20                300
# 26  absolute_error              20                200
# 29  absolute_error              20                500
# 39  absolute_error              50                500
# 16   squared_error              50                200
# 28  absolute_error              20                400
# 38  absolute_error              50                400
# 13   squared_error              35                400
# 18   squared_error              50                400
# 19   squared_error              50                500
# 11   squared_error              35                200
# 32  absolute_error              35                300
# 12   squared_error              35                300
# 7    squared_error              20                300
# 36  absolute_error              50                200
# 9    squared_error              20                500
# 17   squared_error              50                300
# 10   squared_error              35                100
# 8    squared_error              20                400
# 14   squared_error              35                500
# 6    squared_error              20                200
# 53         poisson              35                400
# 15   squared_error              50                100
# 51         poisson              35                200
# 52         poisson              35                300
# 57         poisson              50                300
# 55         poisson              50                100
# 59         poisson              50                500
# 56         poisson              50                200
# 54         poisson              35                500
# 58         poisson              50                400
# 50         poisson              35                100
# 48         poisson              20                400
# 46         poisson              20                200
# 47         poisson              20                300
# 49         poisson              20                500
# 45         poisson              20                100
# 40         poisson               5                100
# 41         poisson               5                200
# 44         poisson               5                500
# 42         poisson               5                300
# 43         poisson               5                400
#
#                                                params  split0_test_score  \
# 23  {'criterion': 'absolute_error', 'max_depth': 5...           0.825996
# 22  {'criterion': 'absolute_error', 'max_depth': 5...           0.824965
# 24  {'criterion': 'absolute_error', 'max_depth': 5...           0.823719
# 21  {'criterion': 'absolute_error', 'max_depth': 5...           0.821666
# 20  {'criterion': 'absolute_error', 'max_depth': 5...           0.821056
# 0   {'criterion': 'squared_error', 'max_depth': 5,...           0.809097
# 2   {'criterion': 'squared_error', 'max_depth': 5,...           0.800823
# 1   {'criterion': 'squared_error', 'max_depth': 5,...           0.802758
# 4   {'criterion': 'squared_error', 'max_depth': 5,...           0.800019
# 3   {'criterion': 'squared_error', 'max_depth': 5,...           0.800788
# 30  {'criterion': 'absolute_error', 'max_depth': 3...           0.780319
# 34  {'criterion': 'absolute_error', 'max_depth': 3...           0.770520
# 25  {'criterion': 'absolute_error', 'max_depth': 2...           0.769053
# 33  {'criterion': 'absolute_error', 'max_depth': 3...           0.762787
# 31  {'criterion': 'absolute_error', 'max_depth': 3...           0.773789
# 5   {'criterion': 'squared_error', 'max_depth': 20...           0.764129
# 37  {'criterion': 'absolute_error', 'max_depth': 5...           0.766886
# 35  {'criterion': 'absolute_error', 'max_depth': 5...           0.761660
# 27  {'criterion': 'absolute_error', 'max_depth': 2...           0.763999
# 26  {'criterion': 'absolute_error', 'max_depth': 2...           0.758297
# 29  {'criterion': 'absolute_error', 'max_depth': 2...           0.760770
# 39  {'criterion': 'absolute_error', 'max_depth': 5...           0.762373
# 16  {'criterion': 'squared_error', 'max_depth': 50...           0.763733
# 28  {'criterion': 'absolute_error', 'max_depth': 2...           0.763559
# 38  {'criterion': 'absolute_error', 'max_depth': 5...           0.761379
# 13  {'criterion': 'squared_error', 'max_depth': 35...           0.757714
# 18  {'criterion': 'squared_error', 'max_depth': 50...           0.755799
# 19  {'criterion': 'squared_error', 'max_depth': 50...           0.754872
# 11  {'criterion': 'squared_error', 'max_depth': 35...           0.757689
# 32  {'criterion': 'absolute_error', 'max_depth': 3...           0.762767
# 12  {'criterion': 'squared_error', 'max_depth': 35...           0.761630
# 7   {'criterion': 'squared_error', 'max_depth': 20...           0.755256
# 36  {'criterion': 'absolute_error', 'max_depth': 5...           0.764007
# 9   {'criterion': 'squared_error', 'max_depth': 20...           0.755552
# 17  {'criterion': 'squared_error', 'max_depth': 50...           0.753843
# 10  {'criterion': 'squared_error', 'max_depth': 35...           0.748610
# 8   {'criterion': 'squared_error', 'max_depth': 20...           0.745541
# 14  {'criterion': 'squared_error', 'max_depth': 35...           0.749565
# 6   {'criterion': 'squared_error', 'max_depth': 20...           0.751925
# 53  {'criterion': 'poisson', 'max_depth': 35, 'n_e...           0.747196
# 15  {'criterion': 'squared_error', 'max_depth': 50...           0.743391
# 51  {'criterion': 'poisson', 'max_depth': 35, 'n_e...           0.742880
# 52  {'criterion': 'poisson', 'max_depth': 35, 'n_e...           0.738357
# 57  {'criterion': 'poisson', 'max_depth': 50, 'n_e...           0.736874
# 55  {'criterion': 'poisson', 'max_depth': 50, 'n_e...           0.737650
# 59  {'criterion': 'poisson', 'max_depth': 50, 'n_e...           0.735324
# 56  {'criterion': 'poisson', 'max_depth': 50, 'n_e...           0.732825
# 54  {'criterion': 'poisson', 'max_depth': 35, 'n_e...           0.733360
# 58  {'criterion': 'poisson', 'max_depth': 50, 'n_e...           0.734730
# 50  {'criterion': 'poisson', 'max_depth': 35, 'n_e...           0.723003
# 48  {'criterion': 'poisson', 'max_depth': 20, 'n_e...           0.680822
# 46  {'criterion': 'poisson', 'max_depth': 20, 'n_e...           0.674692
# 47  {'criterion': 'poisson', 'max_depth': 20, 'n_e...           0.674320
# 49  {'criterion': 'poisson', 'max_depth': 20, 'n_e...           0.676020
# 45  {'criterion': 'poisson', 'max_depth': 20, 'n_e...           0.676327
# 40  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.343358
# 41  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.347476
# 44  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.342152
# 42  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.333021
# 43  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.341956
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 23           0.767703           0.613279         0.735659        0.089749
# 22           0.767552           0.613263         0.735260        0.089393
# 24           0.767032           0.614405         0.735052        0.088393
# 21           0.768712           0.614097         0.734825        0.088063
# 20           0.764548           0.613400         0.733001        0.087661
# 0            0.768083           0.618339         0.731840        0.081985
# 2            0.769916           0.618107         0.729615        0.079851
# 1            0.765328           0.618878         0.728988        0.079345
# 4            0.768145           0.614920         0.727695        0.080798
# 3            0.767020           0.613176         0.726995        0.081654
# 30           0.758531           0.582843         0.707231        0.088404
# 34           0.758975           0.580048         0.703181        0.087196
# 25           0.760038           0.578807         0.702633        0.087636
# 33           0.760495           0.580445         0.701242        0.085421
# 31           0.757701           0.571860         0.701117        0.091634
# 5            0.754191           0.584460         0.700927        0.082454
# 37           0.759442           0.575824         0.700717        0.088365
# 35           0.760719           0.577668         0.700016        0.086514
# 27           0.758147           0.577887         0.700011        0.086388
# 26           0.759041           0.582216         0.699851        0.083181
# 29           0.760204           0.578327         0.699767        0.085872
# 39           0.760702           0.574701         0.699259        0.088078
# 16           0.755379           0.578602         0.699238        0.085371
# 28           0.760382           0.572831         0.698924        0.089171
# 38           0.759929           0.574515         0.698608        0.087749
# 13           0.753765           0.583864         0.698447        0.081039
# 18           0.756134           0.580370         0.697434        0.082777
# 19           0.752917           0.583790         0.697193        0.080192
# 11           0.754114           0.578571         0.696791        0.083607
# 32           0.758839           0.568719         0.696775        0.090564
# 12           0.753665           0.575020         0.696772        0.086153
# 7            0.752806           0.580667         0.696243        0.081731
# 36           0.754303           0.569113         0.695808        0.089674
# 9            0.754093           0.576453         0.695366        0.084086
# 17           0.752903           0.578368         0.695038        0.082499
# 10           0.752297           0.583603         0.694836        0.078668
# 8            0.754002           0.579644         0.693062        0.080273
# 14           0.753489           0.575695         0.692916        0.082904
# 6            0.750987           0.575580         0.692831        0.082910
# 53           0.753806           0.573836         0.691613        0.083325
# 15           0.756567           0.571803         0.690587        0.084165
# 51           0.749464           0.577660         0.690001        0.079483
# 52           0.754814           0.573980         0.689050        0.081644
# 57           0.756459           0.571994         0.688442        0.082729
# 55           0.751577           0.575959         0.688395        0.079707
# 59           0.753822           0.574348         0.687831        0.080600
# 56           0.756195           0.573484         0.687502        0.081185
# 54           0.751897           0.577173         0.687477        0.078363
# 58           0.754521           0.572598         0.687283        0.081496
# 50           0.751989           0.577076         0.684023        0.076543
# 48           0.716201           0.488575         0.628533        0.100013
# 46           0.716471           0.493434         0.628199        0.096808
# 47           0.716580           0.493665         0.628189        0.096674
# 49           0.717056           0.489782         0.627619        0.098895
# 45           0.719265           0.484162         0.626584        0.102222
# 40           0.503514           0.166965         0.337946        0.137449
# 41           0.500012           0.158554         0.335347        0.139663
# 44           0.500811           0.160763         0.334576        0.138928
# 42           0.498995           0.164943         0.332320        0.136377
# 43           0.499368           0.153397         0.331574        0.141432
#
#     rank_test_score
# 23                1
# 22                2
# 24                3
# 21                4
# 20                5
# 0                 6
# 2                 7
# 1                 8
# 4                 9
# 3                10
# 30               11
# 34               12
# 25               13
# 33               14
# 31               15
# 5                16
# 37               17
# 35               18
# 27               19
# 26               20
# 29               21
# 39               22
# 16               23
# 28               24
# 38               25
# 13               26
# 18               27
# 19               28
# 11               29
# 32               30
# 12               31
# 7                32
# 36               33
# 9                34
# 17               35
# 10               36
# 8                37
# 14               38
# 6                39
# 53               40
# 15               41
# 51               42
# 52               43
# 57               44
# 55               45
# 59               46
# 56               47
# 54               48
# 58               49
# 50               50
# 48               51
# 46               52
# 47               53
# 49               54
# 45               55
# 40               56
# 41               57
# 44               58
# 42               59
# 43               60

# %%
grid.best_estimator_
# Out:
# RandomForestRegressor(criterion='absolute_error', max_depth=5, n_estimators=400)

# %%
dump(grid.best_estimator_,"house_pricing_73.pkl")
# Out:
# ['house_pricing_73.pkl']
